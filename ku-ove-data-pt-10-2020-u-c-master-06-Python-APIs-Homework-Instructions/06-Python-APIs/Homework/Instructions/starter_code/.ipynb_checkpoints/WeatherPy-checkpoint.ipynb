# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
units = "imperial"

query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=0fcdae27300d0d35f7c2443882b04849&units=imperial&q=

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_two = []
cloudiness = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("-----------\nData Retrieval Completed\n-----------")
# Out:
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | grindavik
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | dingle
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 10 of Set 1 | nanortalik
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | ucar
# Processing Record 13 of Set 1 | tomatlan
# City not found. Skipping...
# Processing Record 14 of Set 1 | baft
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | ponta do sol
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | ampanihy
# City not found. Skipping...
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | vanavara
# Processing Record 23 of Set 1 | isangel
# Processing Record 24 of Set 1 | camocim
# Processing Record 25 of Set 1 | byron bay
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | carutapera
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | chichimila
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | port macquarie
# City not found. Skipping...
# Processing Record 32 of Set 1 | pangnirtung
# Processing Record 33 of Set 1 | gorele
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | sur
# Processing Record 37 of Set 1 | cidreira
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | provideniya
# City not found. Skipping...
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | banda aceh
# Processing Record 43 of Set 1 | keflavik
# City not found. Skipping...
# Processing Record 44 of Set 1 | grand river south east
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 49 of Set 1 | guerrero negro
# City not found. Skipping...
# Processing Record 1 of Set 2 | sao joao da barra
# Processing Record 2 of Set 2 | colimes
# City not found. Skipping...
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | cayenne
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | tura
# Processing Record 8 of Set 2 | rassvet
# Processing Record 9 of Set 2 | katsuura
# Processing Record 10 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 11 of Set 2 | hasaki
# Processing Record 12 of Set 2 | foso
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | santa cruz
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | cyangugu
# Processing Record 17 of Set 2 | narsaq
# Processing Record 18 of Set 2 | swan hill
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | lucapa
# Processing Record 21 of Set 2 | tuscaloosa
# Processing Record 22 of Set 2 | faanui
# City not found. Skipping...
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | kalmunai
# Processing Record 25 of Set 2 | taunton
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | mae sai
# Processing Record 28 of Set 2 | san patricio
# Processing Record 29 of Set 2 | kodinsk
# Processing Record 30 of Set 2 | pringsewu
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | longyearbyen
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | winnemucca
# Processing Record 35 of Set 2 | dalneye konstantinovo
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | yichang
# Processing Record 39 of Set 2 | tiksi
# Processing Record 40 of Set 2 | tagusao
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | albany
# City not found. Skipping...
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | bredasdorp
# City not found. Skipping...
# Processing Record 45 of Set 2 | niquelandia
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | vozrozhdeniye
# City not found. Skipping...
# Processing Record 48 of Set 2 | shache
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 1 of Set 3 | miyako
# Processing Record 2 of Set 3 | klaksvik
# City not found. Skipping...
# Processing Record 3 of Set 3 | mount gambier
# Processing Record 4 of Set 3 | korem
# Processing Record 5 of Set 3 | corn island
# Processing Record 6 of Set 3 | solnechnyy
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | hadejia
# Processing Record 9 of Set 3 | sorland
# Processing Record 10 of Set 3 | caravelas
# Processing Record 11 of Set 3 | tuatapere
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | golkoy
# Processing Record 14 of Set 3 | lavello
# Processing Record 15 of Set 3 | sumbe
# Processing Record 16 of Set 3 | vao
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | mizdah
# Processing Record 19 of Set 3 | ewa beach
# Processing Record 20 of Set 3 | hualmay
# Processing Record 21 of Set 3 | hamilton
# Processing Record 22 of Set 3 | alice springs
# Processing Record 23 of Set 3 | tabou
# Processing Record 24 of Set 3 | morant bay
# Processing Record 25 of Set 3 | cherskiy
# Processing Record 26 of Set 3 | pimentel
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | afsin
# Processing Record 30 of Set 3 | auki
# Processing Record 31 of Set 3 | ossora
# Processing Record 32 of Set 3 | iracoubo
# Processing Record 33 of Set 3 | wawa
# Processing Record 34 of Set 3 | siderno
# Processing Record 35 of Set 3 | sept-iles
# Processing Record 36 of Set 3 | sedkyrkeshch
# Processing Record 37 of Set 3 | katiola
# Processing Record 38 of Set 3 | bacungan
# Processing Record 39 of Set 3 | kati
# Processing Record 40 of Set 3 | gladstone
# Processing Record 41 of Set 3 | taoudenni
# Processing Record 42 of Set 3 | fairbanks
# Processing Record 43 of Set 3 | atlantic beach
# Processing Record 44 of Set 3 | emba
# Processing Record 45 of Set 3 | constitucion
# Processing Record 46 of Set 3 | coquimbo
# Processing Record 47 of Set 3 | bethel
# Processing Record 48 of Set 3 | moose factory
# Processing Record 49 of Set 3 | kavieng
# Processing Record 1 of Set 4 | deputatskiy
# Processing Record 2 of Set 4 | kharp
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | kiunga
# City not found. Skipping...
# Processing Record 5 of Set 4 | aksarka
# Processing Record 6 of Set 4 | mahibadhoo
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | skibbereen
# Processing Record 9 of Set 4 | mys shmidta
# Processing Record 10 of Set 4 | tapejara
# Processing Record 11 of Set 4 | shingu
# Processing Record 12 of Set 4 | gushikawa
# Processing Record 13 of Set 4 | atar
# Processing Record 14 of Set 4 | mabaruma
# Processing Record 15 of Set 4 | cayambe
# Processing Record 16 of Set 4 | brae
# Processing Record 17 of Set 4 | bathsheba
# Processing Record 18 of Set 4 | maningrida
# Processing Record 19 of Set 4 | makushino
# Processing Record 20 of Set 4 | sterlibashevo
# Processing Record 21 of Set 4 | peterhead
# Processing Record 22 of Set 4 | pundaguitan
# Processing Record 23 of Set 4 | wenling
# Processing Record 24 of Set 4 | bambous virieux
# Processing Record 25 of Set 4 | angoche
# Processing Record 26 of Set 4 | giyani
# Processing Record 27 of Set 4 | taman
# Processing Record 28 of Set 4 | urucui
# City not found. Skipping...
# Processing Record 29 of Set 4 | pueblo nuevo
# Processing Record 30 of Set 4 | gazli
# Processing Record 31 of Set 4 | huarmey
# Processing Record 32 of Set 4 | umea
# Processing Record 33 of Set 4 | laukaa
# Processing Record 34 of Set 4 | dhankuta
# Processing Record 35 of Set 4 | chokwe
# City not found. Skipping...
# Processing Record 36 of Set 4 | terrace
# Processing Record 37 of Set 4 | hailey
# Processing Record 38 of Set 4 | san jeronimo
# City not found. Skipping...
# Processing Record 39 of Set 4 | usman
# Processing Record 40 of Set 4 | eirunepe
# Processing Record 41 of Set 4 | esperance
# Processing Record 42 of Set 4 | nioaque
# Processing Record 43 of Set 4 | yumen
# Processing Record 44 of Set 4 | victoria
# Processing Record 45 of Set 4 | bowen
# Processing Record 46 of Set 4 | vila franca do campo
# Processing Record 47 of Set 4 | porto santo
# City not found. Skipping...
# Processing Record 48 of Set 4 | poso
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 1 of Set 5 | xichang
# Processing Record 2 of Set 5 | marzuq
# Processing Record 3 of Set 5 | marawi
# Processing Record 4 of Set 5 | khromtau
# Processing Record 5 of Set 5 | manta
# Processing Record 6 of Set 5 | havoysund
# City not found. Skipping...
# Processing Record 7 of Set 5 | verkhoyansk
# Processing Record 8 of Set 5 | san cristobal
# Processing Record 9 of Set 5 | christchurch
# Processing Record 10 of Set 5 | lobito
# Processing Record 11 of Set 5 | pilar
# City not found. Skipping...
# Processing Record 12 of Set 5 | arlit
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | carnarvon
# Processing Record 15 of Set 5 | siedlce
# Processing Record 16 of Set 5 | tuktoyaktuk
# Processing Record 17 of Set 5 | taltal
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | tirodi
# Processing Record 20 of Set 5 | egvekinot
# Processing Record 21 of Set 5 | alofi
# Processing Record 22 of Set 5 | marsa matruh
# Processing Record 23 of Set 5 | margate
# Processing Record 24 of Set 5 | souillac
# City not found. Skipping...
# Processing Record 25 of Set 5 | hovd
# Processing Record 26 of Set 5 | oranjestad
# Processing Record 27 of Set 5 | lebu
# Processing Record 28 of Set 5 | katobu
# Processing Record 29 of Set 5 | wanning
# Processing Record 30 of Set 5 | kailua
# Processing Record 31 of Set 5 | honiara
# Processing Record 32 of Set 5 | pacific grove
# Processing Record 33 of Set 5 | makinsk
# City not found. Skipping...
# Processing Record 34 of Set 5 | sistranda
# Processing Record 35 of Set 5 | zheleznodorozhnyy
# Processing Record 36 of Set 5 | antigonish
# City not found. Skipping...
# Processing Record 37 of Set 5 | naze
# Processing Record 38 of Set 5 | bestobe
# Processing Record 39 of Set 5 | honningsvag
# Processing Record 40 of Set 5 | ugoofaaru
# Processing Record 41 of Set 5 | kathu
# Processing Record 42 of Set 5 | manado
# Processing Record 43 of Set 5 | port elizabeth
# Processing Record 44 of Set 5 | saint-pierre
# City not found. Skipping...
# Processing Record 45 of Set 5 | odweyne
# Processing Record 46 of Set 5 | faya
# Processing Record 47 of Set 5 | kabwe
# Processing Record 48 of Set 5 | grand-santi
# Processing Record 49 of Set 5 | udachnyy
# Processing Record 1 of Set 6 | atlantic city
# Processing Record 2 of Set 6 | yatou
# Processing Record 3 of Set 6 | marondera
# Processing Record 4 of Set 6 | saint-donat-de-montcalm
# Processing Record 5 of Set 6 | nara
# Processing Record 6 of Set 6 | bintulu
# Processing Record 7 of Set 6 | adre
# Processing Record 8 of Set 6 | litoral del san juan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 6 | upernavik
# Processing Record 10 of Set 6 | ambulu
# City not found. Skipping...
# Processing Record 11 of Set 6 | derzhavinsk
# Processing Record 12 of Set 6 | ribeira grande
# Processing Record 13 of Set 6 | kasongo-lunda
# City not found. Skipping...
# Processing Record 14 of Set 6 | nexo
# Processing Record 15 of Set 6 | lompoc
# Processing Record 16 of Set 6 | menzelinsk
# Processing Record 17 of Set 6 | padang
# Processing Record 18 of Set 6 | chuy
# Processing Record 19 of Set 6 | bila tserkva
# Processing Record 20 of Set 6 | herat
# Processing Record 21 of Set 6 | codrington
# Processing Record 22 of Set 6 | mango
# Processing Record 23 of Set 6 | yeppoon
# Processing Record 24 of Set 6 | awjilah
# Processing Record 25 of Set 6 | oranjemund
# Processing Record 26 of Set 6 | srednekolymsk
# Processing Record 27 of Set 6 | samarai
# Processing Record 28 of Set 6 | toropets
# Processing Record 29 of Set 6 | yeovil
# City not found. Skipping...
# Processing Record 30 of Set 6 | asau
# Processing Record 31 of Set 6 | shelburne
# Processing Record 32 of Set 6 | kindu
# Processing Record 33 of Set 6 | antofagasta
# Processing Record 34 of Set 6 | san quintin
# Processing Record 35 of Set 6 | sieghartskirchen
# Processing Record 36 of Set 6 | lagoa
# Processing Record 37 of Set 6 | riesa
# Processing Record 38 of Set 6 | smithers
# Processing Record 39 of Set 6 | seoul
# Processing Record 40 of Set 6 | carmen
# Processing Record 41 of Set 6 | zimovniki
# Processing Record 42 of Set 6 | adrar
# Processing Record 43 of Set 6 | san joaquin
# Processing Record 44 of Set 6 | port hedland
# Processing Record 45 of Set 6 | lamar
# Processing Record 46 of Set 6 | yurla
# Processing Record 47 of Set 6 | vostok
# Processing Record 48 of Set 6 | nabire
# Processing Record 49 of Set 6 | paita
# Processing Record 1 of Set 7 | torbay
# Processing Record 2 of Set 7 | lichinga
# Processing Record 3 of Set 7 | progreso
# Processing Record 4 of Set 7 | tornio
# Processing Record 5 of Set 7 | siniscola
# Processing Record 6 of Set 7 | ouadda
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 7 | beringovskiy
# Processing Record 8 of Set 7 | champa
# Processing Record 9 of Set 7 | chara
# Processing Record 10 of Set 7 | robertsport
# Processing Record 11 of Set 7 | makakilo city
# Processing Record 12 of Set 7 | camacha
# Processing Record 13 of Set 7 | ono
# Processing Record 14 of Set 7 | englehart
# Processing Record 15 of Set 7 | nouakchott
# Processing Record 16 of Set 7 | camrose
# Processing Record 17 of Set 7 | ternuvate
# Processing Record 18 of Set 7 | kholodnyy
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | manitouwadge
# Processing Record 21 of Set 7 | tessalit
# Processing Record 22 of Set 7 | miyata
# Processing Record 23 of Set 7 | yurginskoye
# Processing Record 24 of Set 7 | juneau
# Processing Record 25 of Set 7 | port lincoln
# Processing Record 26 of Set 7 | santa vitoria do palmar
# Processing Record 27 of Set 7 | corinto
# Processing Record 28 of Set 7 | vaitape
# Processing Record 29 of Set 7 | maiduguri
# Processing Record 30 of Set 7 | leningradskiy
# Processing Record 31 of Set 7 | vanimo
# Processing Record 32 of Set 7 | ostrovnoy
# Processing Record 33 of Set 7 | longfeng
# Processing Record 34 of Set 7 | lieksa
# Processing Record 35 of Set 7 | chaoyang
# Processing Record 36 of Set 7 | maraba
# Processing Record 37 of Set 7 | billings
# Processing Record 38 of Set 7 | calama
# City not found. Skipping...
# Processing Record 39 of Set 7 | trinidad
# Processing Record 40 of Set 7 | medianeira
# Processing Record 41 of Set 7 | olafsvik
# Processing Record 42 of Set 7 | bubaque
# Processing Record 43 of Set 7 | gilgit
# Processing Record 44 of Set 7 | ocean city
# Processing Record 45 of Set 7 | uryupinsk
# Processing Record 46 of Set 7 | cam pha
# Processing Record 47 of Set 7 | lata
# Processing Record 48 of Set 7 | weinsberg
# Processing Record 49 of Set 7 | berlevag
# Processing Record 1 of Set 8 | corner brook
# Processing Record 2 of Set 8 | gaur
# Processing Record 3 of Set 8 | thinadhoo
# Processing Record 4 of Set 8 | altamira
# Processing Record 5 of Set 8 | somerset east
# Processing Record 6 of Set 8 | zharkent
# Processing Record 7 of Set 8 | kumano
# Processing Record 8 of Set 8 | casper
# Processing Record 9 of Set 8 | praia
# Processing Record 10 of Set 8 | awbari
# Processing Record 11 of Set 8 | neuquen
# Processing Record 12 of Set 8 | aginskoye
# Processing Record 13 of Set 8 | mandera
# Processing Record 14 of Set 8 | tautira
# Processing Record 15 of Set 8 | talnakh
# Processing Record 16 of Set 8 | bayir
# Processing Record 17 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 8 | ulagan
# Processing Record 19 of Set 8 | easthampton
# Processing Record 20 of Set 8 | grand gaube
# Processing Record 21 of Set 8 | nova aurora
# Processing Record 22 of Set 8 | muros
# Processing Record 23 of Set 8 | fort nelson
# Processing Record 24 of Set 8 | saint-ambroise
# Processing Record 25 of Set 8 | anadyr
# Processing Record 26 of Set 8 | northam
# City not found. Skipping...
# Processing Record 27 of Set 8 | ambilobe
# Processing Record 28 of Set 8 | yurino
# Processing Record 29 of Set 8 | villamontes
# Processing Record 30 of Set 8 | jacareacanga
# Processing Record 31 of Set 8 | abu jubayhah
# Processing Record 32 of Set 8 | nyurba
# Processing Record 33 of Set 8 | udon thani
# Processing Record 34 of Set 8 | kolondieba
# Processing Record 35 of Set 8 | paris
# Processing Record 36 of Set 8 | bajo baudo
# Processing Record 37 of Set 8 | gaya
# Processing Record 38 of Set 8 | tual
# Processing Record 39 of Set 8 | zhifang
# Processing Record 40 of Set 8 | havre-saint-pierre
# Processing Record 41 of Set 8 | lavrentiya
# Processing Record 42 of Set 8 | energeticheskiy
# Processing Record 43 of Set 8 | mumbwa
# Processing Record 44 of Set 8 | lazarev
# Processing Record 45 of Set 8 | eyl
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | quelimane
# City not found. Skipping...
# Processing Record 48 of Set 8 | lhokseumawe
# Processing Record 49 of Set 8 | tera
# Processing Record 1 of Set 9 | palmer
# Processing Record 2 of Set 9 | taseyevo
# Processing Record 3 of Set 9 | santa rosa
# Processing Record 4 of Set 9 | vadso
# Processing Record 5 of Set 9 | aklavik
# Processing Record 6 of Set 9 | touros
# City not found. Skipping...
# Processing Record 7 of Set 9 | ginir
# Processing Record 8 of Set 9 | bengbu
# Processing Record 9 of Set 9 | marsh harbour
# Processing Record 10 of Set 9 | neringa
# Processing Record 11 of Set 9 | linxia
# Processing Record 12 of Set 9 | lewistown
# Processing Record 13 of Set 9 | fortuna
# Processing Record 14 of Set 9 | kattivakkam
# Processing Record 15 of Set 9 | sitka
# Processing Record 16 of Set 9 | pyay
# Processing Record 17 of Set 9 | trincomalee
# Processing Record 18 of Set 9 | dunedin
# Processing Record 19 of Set 9 | coihaique
# Processing Record 20 of Set 9 | ahipara
# Processing Record 21 of Set 9 | lakselv
# Processing Record 22 of Set 9 | ruidoso
# Processing Record 23 of Set 9 | portage
# Processing Record 24 of Set 9 | karratha
# Processing Record 25 of Set 9 | pecos
# City not found. Skipping...
# Processing Record 26 of Set 9 | kununurra
# Processing Record 27 of Set 9 | kamaishi
# Processing Record 28 of Set 9 | irece
# Processing Record 29 of Set 9 | igrim
# Processing Record 30 of Set 9 | kalemie
# Processing Record 31 of Set 9 | pangody
# Processing Record 32 of Set 9 | lasa
# Processing Record 33 of Set 9 | pisco
# Processing Record 34 of Set 9 | beecher
# Processing Record 35 of Set 9 | arman
# Processing Record 36 of Set 9 | beloha
# Processing Record 37 of Set 9 | little chute
# Processing Record 38 of Set 9 | medvezhyegorsk
# Processing Record 39 of Set 9 | comodoro rivadavia
# Processing Record 40 of Set 9 | sambava
# Processing Record 41 of Set 9 | hobyo
# City not found. Skipping...
# Processing Record 42 of Set 9 | poum
# Processing Record 43 of Set 9 | zabid
# Processing Record 44 of Set 9 | wewak
# Processing Record 45 of Set 9 | lahat
# Processing Record 46 of Set 9 | longkou
# City not found. Skipping...
# Processing Record 47 of Set 9 | vilhena
# Processing Record 48 of Set 9 | okhotsk
# Processing Record 49 of Set 9 | ilhabela
# Processing Record 1 of Set 10 | mercedes
# Processing Record 2 of Set 10 | sinnai
# Processing Record 3 of Set 10 | seminole
# Processing Record 4 of Set 10 | nantucket
# City not found. Skipping...
# Processing Record 5 of Set 10 | haines junction
# Processing Record 6 of Set 10 | tiznit
# Processing Record 7 of Set 10 | fertorakos
# Processing Record 8 of Set 10 | okha
# Processing Record 9 of Set 10 | shreveport
# City not found. Skipping...
# Processing Record 10 of Set 10 | namibe
# Processing Record 11 of Set 10 | pravda
# Processing Record 12 of Set 10 | flin flon
# Processing Record 13 of Set 10 | manikganj
# Processing Record 14 of Set 10 | antalaha
# Processing Record 15 of Set 10 | dhidhdhoo
# Processing Record 16 of Set 10 | tigzirt
# Processing Record 17 of Set 10 | kotido
# Processing Record 18 of Set 10 | nuuk
# Processing Record 19 of Set 10 | araouane
# Processing Record 20 of Set 10 | haldibari
# Processing Record 21 of Set 10 | igarka
# Processing Record 22 of Set 10 | khandagayty
# City not found. Skipping...
# Processing Record 23 of Set 10 | katherine
# Processing Record 24 of Set 10 | orda
# Processing Record 25 of Set 10 | moranbah
# Processing Record 26 of Set 10 | shimoda
# Processing Record 27 of Set 10 | batagay-alyta
# Processing Record 28 of Set 10 | teguise
# Processing Record 29 of Set 10 | ronne
# Processing Record 30 of Set 10 | eenhana
# Processing Record 31 of Set 10 | bandarbeyla
# Processing Record 32 of Set 10 | bingol
# Processing Record 33 of Set 10 | severo-yeniseyskiy
# Processing Record 34 of Set 10 | agadez
# Processing Record 35 of Set 10 | anchorage
# Processing Record 36 of Set 10 | kirkwood
# Processing Record 37 of Set 10 | bayan
# City not found. Skipping...
# Processing Record 38 of Set 10 | whitecourt
# Processing Record 39 of Set 10 | pachino
# Processing Record 40 of Set 10 | barrhead
# Processing Record 41 of Set 10 | north bend
# Processing Record 42 of Set 10 | arraial do cabo
# Processing Record 43 of Set 10 | abu samrah
# Processing Record 44 of Set 10 | pangkalanbuun
# Processing Record 45 of Set 10 | semnan
# Processing Record 46 of Set 10 | vila velha
# Processing Record 47 of Set 10 | nampula
# Processing Record 48 of Set 10 | caronport
# Processing Record 49 of Set 10 | marrakesh
# Processing Record 1 of Set 11 | san ignacio
# Processing Record 2 of Set 11 | veisiejai
# Processing Record 3 of Set 11 | husavik
# Processing Record 4 of Set 11 | caconda
# Processing Record 5 of Set 11 | buraydah
# Processing Record 6 of Set 11 | pasinler
# Processing Record 7 of Set 11 | luanda
# Processing Record 8 of Set 11 | banfora
# Processing Record 9 of Set 11 | linhares
# Processing Record 10 of Set 11 | miracema do tocantins
# Processing Record 11 of Set 11 | arona
# Processing Record 12 of Set 11 | pedasi
# Processing Record 13 of Set 11 | meulaboh
# Processing Record 14 of Set 11 | san andres
# Processing Record 15 of Set 11 | mehriz
# Processing Record 16 of Set 11 | sola
# Processing Record 17 of Set 11 | nizhneangarsk
# Processing Record 18 of Set 11 | goderich
# Processing Record 19 of Set 11 | amapa
# Processing Record 20 of Set 11 | knokke-heist
# Processing Record 21 of Set 11 | itarema
# Processing Record 22 of Set 11 | kerema
# Processing Record 23 of Set 11 | lubao
# Processing Record 24 of Set 11 | boksitogorsk
# Processing Record 25 of Set 11 | naro moru
# Processing Record 26 of Set 11 | mendi
# Processing Record 27 of Set 11 | douglas
# City not found. Skipping...
# Processing Record 28 of Set 11 | paramirim
# Processing Record 29 of Set 11 | yulara
# Processing Record 30 of Set 11 | sosnovo
# Processing Record 31 of Set 11 | kaeo
# Processing Record 32 of Set 11 | maltahohe
# Processing Record 33 of Set 11 | aras
# Processing Record 34 of Set 11 | evensk
# Processing Record 35 of Set 11 | axim
# Processing Record 36 of Set 11 | kulunda
# City not found. Skipping...
# Processing Record 37 of Set 11 | puerto asis
# Processing Record 38 of Set 11 | kamenka
# Processing Record 39 of Set 11 | san pedro de lloc
# Processing Record 40 of Set 11 | mount holly
# Processing Record 41 of Set 11 | zhigansk
# Processing Record 42 of Set 11 | qaqortoq
# Processing Record 43 of Set 11 | saint-felicien
# Processing Record 44 of Set 11 | anito
# City not found. Skipping...
# Processing Record 45 of Set 11 | salmas
# Processing Record 46 of Set 11 | bilma
# Processing Record 47 of Set 11 | whitehorse
# Processing Record 48 of Set 11 | omsukchan
# Processing Record 49 of Set 11 | launceston
# Processing Record 1 of Set 12 | thasra
# Processing Record 2 of Set 12 | yar-sale
# Processing Record 3 of Set 12 | almaty
# Processing Record 4 of Set 12 | mahajanga
# Processing Record 5 of Set 12 | kahului
# Processing Record 6 of Set 12 | mayo
# Processing Record 7 of Set 12 | oudtshoorn
# Processing Record 8 of Set 12 | saint-georges
# Processing Record 9 of Set 12 | hambantota
# Processing Record 10 of Set 12 | millinocket
# Processing Record 11 of Set 12 | viedma
# Processing Record 12 of Set 12 | kvitok
# Processing Record 13 of Set 12 | turayf
# Processing Record 14 of Set 12 | raudeberg
# Processing Record 15 of Set 12 | gizo
# City not found. Skipping...
# Processing Record 16 of Set 12 | daru
# Processing Record 17 of Set 12 | helong
# Processing Record 18 of Set 12 | conway
# Processing Record 19 of Set 12 | manakara
# Processing Record 20 of Set 12 | fereydun kenar
# Processing Record 21 of Set 12 | bakchar
# Processing Record 22 of Set 12 | port-gentil
# City not found. Skipping...
# Processing Record 23 of Set 12 | puerto baquerizo moreno
# Processing Record 24 of Set 12 | biak
# Processing Record 25 of Set 12 | slavutych
# Processing Record 26 of Set 12 | mayumba
# Processing Record 27 of Set 12 | kirakira
# Processing Record 28 of Set 12 | homestead
# Processing Record 29 of Set 12 | kaitangata
# Processing Record 30 of Set 12 | wukari
# City not found. Skipping...
# Processing Record 31 of Set 12 | bairiki
# Processing Record 32 of Set 12 | sokolo
# Processing Record 33 of Set 12 | malindi
# Processing Record 34 of Set 12 | bara
# Processing Record 35 of Set 12 | beisfjord
# Processing Record 36 of Set 12 | marang
# City not found. Skipping...
# Processing Record 37 of Set 12 | ukiah
# Processing Record 38 of Set 12 | burnie
# Processing Record 39 of Set 12 | turbat
# Processing Record 40 of Set 12 | baoro
# Processing Record 41 of Set 12 | laguna
# Processing Record 42 of Set 12 | erenhot
# Processing Record 43 of Set 12 | kandi
# Processing Record 44 of Set 12 | magdagachi
# Processing Record 45 of Set 12 | riohacha
# -----------
# Data Retrieval Completed
# -----------

# %%
weather_dictionary = {
                "City": city_two,
                "Cloudiness": cloudiness,
                "Country": countries,
                "Date": dates,
                "Humidity": humidities,
                "Lat": lats,
                "Lng": lngs,
                "Max Temp": max_temps,
                "Wind Speed": wind_speeds
}

# %%
#Humidity Check - None are over 100%
weather_dictionary_df = pd.DataFrame(weather_dictionary)
weather_dictionary_df.sort_values(by='Wind Speed')
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 380           tual           5      ID  1607392662        68  -5.67  132.75
# 96          shache         100      CN  1607392311        96  38.42   77.24
# 440       ilhabela         100      BR  1607392672        90 -23.78  -45.36
# 64        cyangugu          11      RW  1607392600        88  -2.48   28.91
# 329         maraba         100      BR  1607392216        92  -5.37  -49.12
# ..             ...         ...     ...         ...       ...    ...     ...
# 162           brae         100      GB  1607392276        93  60.40   -1.35
# 85   mar del plata          90      ES  1607392295        93  43.40   -4.01
# 543        kahului          40      US  1607392321        65  20.89 -156.47
# 173          taman           0      RU  1607392619        79  45.21   36.72
# 357        talnakh          90      RU  1607392298        75  69.49   88.40
#
#      Max Temp  Wind Speed
# 380     84.42        0.25
# 96      15.64        0.36
# 440     73.26        0.36
# 64      59.49        0.47
# 329     75.15        0.56
# ..        ...         ...
# 162     46.40       26.40
# 85      46.99       26.40
# 543     82.40       26.40
# 173     24.80       31.32
# 357    -14.80       31.32
#
# [584 rows x 9 columns]

# %%
#No humidity over 100 so this is clean data frame
clean_city_data = weather_dictionary_df

#Export data frame to csv
clean_city_data.to_csv('clean_city_data.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Max Temp"], marker='o',s=30, edgecolors= "black")
plt.title("City Latitude vs Max Temperature")

plt.ylim(0,100)
plt.xlim(-60, 80)

plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig("LAT VS TEMP.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Humidity"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity Level (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('LAT VS HUM.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Cloudiness"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness Level (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('LAT VS CLOUD.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Wind Speed"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('LAT VS WIND.png')

# %% [markdown]
# ## Linear Regression

# %%
north_hemisphere = clean_city_data.loc[clean_city_data['Lat']>0.01]
south_hemisphere = clean_city_data.loc[clean_city_data['Lat']<-0.01]

north_hemisphere.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   butaritari          19      KI  1607392188        76   3.07  172.79
# 2    grindavik          90      IS  1607392391       100  63.84  -22.43
# 4  yellowknife          20      CA  1607392289        85  62.46 -114.35
# 5       dingle          66      PH  1607392282        78  11.00  122.67
# 7  clyde river          99      US  1607392342        70  41.30  -82.98
#
#    Max Temp  Wind Speed
# 0     81.72        9.04
# 2     37.40       13.87
# 4     10.40        8.05
# 5     84.78        6.71
# 7     34.00        9.17

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hemisphere['Lat']
y_values = north_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"red")

plt.ylim(0,100)
plt.xlim(0,85)

plt.ylabel("Max Temp")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hemisphere['Lat']
y_values = south_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"red")

plt.ylim(30, 100)
plt.xlim(-60, 5)

plt.ylabel("Max Temp")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hemisphere['Lat']
y_values = north_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"red")

plt.ylim(0,105)
plt.xlim(0,85)

plt.ylabel("Max Temp")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hemisphere['Lat']
y_values = south_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"red")

plt.ylim(0, 105)
plt.xlim(-60, 5)

plt.ylabel("Max Temp")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hemisphere['Lat']
y_values = north_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"red")

plt.ylim(-5,105)
plt.xlim(0,85)

plt.ylabel("Max Temp")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hemisphere['Lat']
y_values = south_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"red")

plt.ylim(0, 105)
plt.xlim(-60, 5)

plt.ylabel("Max Temp")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hemisphere['Lat']
y_values = north_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"red")

plt.ylim(-2,105)
plt.xlim(0,85)

plt.ylabel("Max Temp")
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hemisphere['Lat']
y_values = south_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"red")

plt.ylim(-2, 105)
plt.xlim(-60, 5)

plt.ylabel("Max Temp")
plt.xlabel('Latitude')
plt.show()
